# %%
import subprocess
import pandas as pd
from io import StringIO

print('hello')
sizes = [2**x for x in range(17)]
results =[]
# df = pd.read_csv(TESTDATA)['time'].describe()
df = pd.DataFrame()
for size in sizes:
    TESTDATA = StringIO(subprocess.run(["./client", "172.30.172.177", str(size)], capture_output=True).stdout.decode("utf-8"))
    df[f"{size}"] = pd.read_csv(TESTDATA)['time']
    # results.append({
    #     "size": size,
    #     "min": df["min"],
    #     "max": df["max"],
    #     "mean": df["mean"]
    # })
# Out:
# hello

# %%
df.boxplot(showfliers=False)
df.describe()
# Out:
#                  1            2            4            8           16  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    162.354000   170.644000   165.125000   150.155000   145.803000
# std      41.418887   124.482992    41.750527    26.839697    13.417833
# min     127.000000   126.000000   120.000000   110.000000    89.000000
# 25%     150.000000   147.000000   146.750000   139.000000   138.000000
# 50%     156.000000   155.000000   155.000000   145.500000   144.000000
# 75%     166.000000   169.000000   169.000000   155.000000   150.000000
# max     996.000000  2971.000000   677.000000   764.000000   280.000000
#
#                 32           64          128          256          512  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    164.391000   145.176000   152.712000   162.521000   173.090000
# std     134.711214    25.326477    19.158709    24.139268   247.947381
# ...
